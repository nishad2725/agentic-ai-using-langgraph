# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "I. Introduction\n    A. Overview of Artificial Intelligence (AI)\n    B. Significance of AI in India\n    C. Purpose of the blog\n\nII. Historical Background of AI in India\n    A. Evolution of AI technologies in India\n    B. Adoption of AI in various industries\n    C. Government initiatives to promote AI research and development\n\nIII. Current Scenario of AI in India\n    A. Growth of AI startups in India\n    B. Key players in the Indian AI market\n    C. Challenges faced by the AI industry in India\n\nIV. Impact of AI on Indian Economy\n    A. Contribution of AI to GDP growth\n    B. Job creation and automation in India\n    C. Potential benefits and risks of AI adoption in India\n\nV. Future Prospects of AI in India\n    A. Emerging trends in AI technology\n    B. Opportunities for AI innovation in India\n    C. Role of AI in shaping India's digital future\n\nVI. Case Studies: AI implementation in India\n    A. Healthcare sector\n    B. Agriculture sector\n    C. Education sector\n\nVII. Ethical and Legal Implications of AI in India\n    A. Data privacy concerns\n    B. Bias and discrimination in AI algorithms\n    C. Regulatory framework for AI in India\n\nVIII. Conclusion\n    A. Summary of key points\n    B. Outlook for the future of AI in India\n    C. Call to action for readers to stay informed on the latest developments in AI in India.", 'content': "Artificial intelligence (AI) has emerged as a transformative technology that is revolutionizing various sectors across the globe. In India, the rise of AI is significantly impacting the economy, driving innovation, and transforming industries. This blog will delve into the evolution of AI in India, its current scenario, its impact on the Indian economy, and the future prospects of AI in the country.\n\nI. Introduction\nA. Overview of Artificial Intelligence (AI): AI is a branch of computer science that aims to create intelligent machines capable of performing tasks that typically require human intelligence, such as decision-making, problem-solving, and speech recognition.\nB. Significance of AI in India: AI has the potential to drive economic growth, improve efficiency, enhance productivity, and create new opportunities for businesses and consumers in India.\nC. Purpose of the blog: The blog aims to provide a comprehensive overview of the rise of AI in India, exploring its historical background, current scenario, impact on the economy, future prospects, case studies of AI implementation in various sectors, and the ethical and legal implications of AI in India.\n\nII. Historical Background of AI in India\nA. Evolution of AI technologies in India: India has made significant strides in AI research and development over the years, with the establishment of research institutions, academic programs, and collaborations with international organizations.\nB. Adoption of AI in various industries: Industries such as healthcare, agriculture, education, finance, and manufacturing in India have started incorporating AI technologies to improve operational efficiency, enhance decision-making, and deliver personalized services to customers.\nC. Government initiatives to promote AI research and development: The Indian government has launched various initiatives such as the National AI Strategy, AI Task Force, and Startup India program to promote AI innovation and entrepreneurship in the country.\n\nIII. Current Scenario of AI in India\nA. Growth of AI startups in India: The Indian AI ecosystem has witnessed a surge in startup activity, with several AI startups emerging in areas such as healthcare, fintech, e-commerce, and cybersecurity.\nB. Key players in the Indian AI market: Indian companies such as Wipro, Infosys, TCS, and startups like Flipkart, Zomato, and Ola are actively investing in AI technologies to drive business growth and innovation.\nC. Challenges faced by the AI industry in India: Challenges such as talent shortage, lack of data ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Overview of Artificial Intelligence (AI)
#     B. Significance of AI in India
#     C. Purpose of the blog
#
# II. Historical Background of AI in India
#     A. Evolution of AI technologies in India
#     B. Adoption of AI in various industries
#     C. Government initiatives to promote AI research and development
#
# III. Current Scenario of AI in India
#     A. Growth of AI startups in India
#     B. Key players in the Indian AI market
#     C. Challenges faced by the AI industry in India
#
# IV. Impact of AI on Indian Economy
#     A. Contribution of AI to GDP growth
#     B. Job creation and automation in India
#     C. Potential benefits and risks of AI adoption in India
#
# V. Future Prospects of AI in India
#     A. Emerging trends in AI technology
#     B. Opportunities for AI innovation in India
#     C. Role of AI in shaping India's digital future
#
# VI. Case Studies: AI implementation in India
#     A. Healthcare sector
#     B. Agriculture sector
#     C. Education sector
#
# VII. Ethical and Legal Implications of AI in India
#     A. Data privacy concerns
#     B. Bias and discrimination in AI algorithms
#     C. Regulatory framework for AI in India
#
# VIII. Conclusion
#     A. Summary of key points
#     B. Outlook for the future of AI in India
#     C. Call to action for readers to stay informed on the latest developments in AI in India.

# %%
print(final_state['content'])
# Out:
# Artificial intelligence (AI) has emerged as a transformative technology that is revolutionizing various sectors across the globe. In India, the rise of AI is significantly impacting the economy, driving innovation, and transforming industries. This blog will delve into the evolution of AI in India, its current scenario, its impact on the Indian economy, and the future prospects of AI in the country.
#
# I. Introduction
# A. Overview of Artificial Intelligence (AI): AI is a branch of computer science that aims to create intelligent machines capable of performing tasks that typically require human intelligence, such as decision-making, problem-solving, and speech recognition.
# B. Significance of AI in India: AI has the potential to drive economic growth, improve efficiency, enhance productivity, and create new opportunities for businesses and consumers in India.
# C. Purpose of the blog: The blog aims to provide a comprehensive overview of the rise of AI in India, exploring its historical background, current scenario, impact on the economy, future prospects, case studies of AI implementation in various sectors, and the ethical and legal implications of AI in India.
#
# II. Historical Background of AI in India
# A. Evolution of AI technologies in India: India has made significant strides in AI research and development over the years, with the establishment of research institutions, academic programs, and collaborations with international organizations.
# B. Adoption of AI in various industries: Industries such as healthcare, agriculture, education, finance, and manufacturing in India have started incorporating AI technologies to improve operational efficiency, enhance decision-making, and deliver personalized services to customers.
# C. Government initiatives to promote AI research and development: The Indian government has launched various initiatives such as the National AI Strategy, AI Task Force, and Startup India program to promote AI innovation and entrepreneurship in the country.
#
# III. Current Scenario of AI in India
# A. Growth of AI startups in India: The Indian AI ecosystem has witnessed a surge in startup activity, with several AI startups emerging in areas such as healthcare, fintech, e-commerce, and cybersecurity.
# B. Key players in the Indian AI market: Indian companies such as Wipro, Infosys, TCS, and startups like Flipkart, Zomato, and Ola are actively investing in AI technologies to drive business growth and innovation.
# C. Challenges faced by the AI industry in India: Challenges such as talent shortage, lack of data infrastructure, regulatory hurdles, and ethical concerns pose obstacles to the widespread adoption of AI in India.
#
# IV. Impact of AI on Indian Economy
# A. Contribution of AI to GDP growth: AI has the potential to contribute significantly to India's GDP growth by boosting productivity, creating new job opportunities, and driving innovation in key sectors.
# B. Job creation and automation in India: While AI has the potential to create new jobs in emerging technologies, there are concerns about job displacement due to automation in traditional industries.
# C. Potential benefits and risks of AI adoption in India: The adoption of AI technologies in India offers opportunities for economic growth, enhanced competitiveness, and improved quality of life, but also raises concerns about ethical issues, data privacy, and societal impacts.
#
# V. Future Prospects of AI in India
# A. Emerging trends in AI technology: Emerging trends such as reinforcement learning, natural language processing, computer vision, and AI-powered robotics are expected to drive innovation and create new opportunities in the Indian AI market.
# B. Opportunities for AI innovation in India: Opportunities for AI innovation in India include the development of AI-powered solutions for healthcare, agriculture, smart cities, education, and cybersecurity.
# C. Role of AI in shaping India's digital future: AI is poised to play a pivotal role in shaping India's digital future by driving digital transformation, enhancing competitiveness, and redefining the way businesses and governments operate.
#
# VI. Case Studies: AI implementation in India
# A. Healthcare sector: AI applications in healthcare include predictive analytics for patient diagnosis, personalized medicine, telemedicine, and medical image analysis.
# B. Agriculture sector: AI technologies in agriculture are being used for crop monitoring, yield prediction, pest detection, soil analysis, and smart farming.
# C. Education sector: AI applications in education include personalized learning, adaptive assessments, virtual tutors, and AI-powered educational platforms.
#
# VII. Ethical and Legal Implications of AI in India
# A. Data privacy concerns: The use of AI technologies raises concerns about data privacy, security, and the potential misuse of personal data by companies and governments.
# B. Bias and discrimination in AI algorithms: AI algorithms can exhibit bias and discrimination due to biased training data, algorithmic errors, and lack of transparency in decision-making.
# C. Regulatory framework for AI in India: India needs a robust regulatory framework to address ethical and legal issues related to AI, including data protection, bias mitigation, accountability, and transparency.
#
# VIII. Conclusion
# A. Summary of key points: The rise of AI in India presents immense opportunities for economic growth, innovation, and prosperity, but also poses challenges related to talent shortage, ethical concerns, and regulatory issues.
# B. Outlook for the future of AI in India: The future of AI in India looks promising, with increased investment in research and development, adoption of AI technologies across industries, and the emergence of new AI startups and innovations.
# C. Call to action for readers to stay informed on the latest developments in AI in India: Readers are encouraged to stay updated on the latest trends, innovations, and policy developments in the Indian AI ecosystem to harness the full potential of AI for economic and social progress.
#
# In conclusion, the rise of AI in India is bringing about a new era of digital transformation, innovation, and growth, with the potential to reshape industries, create new opportunities, and improve the quality of life for millions of people. As India continues to embrace AI technologies, it is crucial for policymakers, businesses, and society to address the challenges, harness the opportunities, and navigate the ethical and legal implications of AI adoption for a sustainable and inclusive digital future.
